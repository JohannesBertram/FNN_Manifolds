# %%
import numpy as np

enc = np.load("enc_mfds/VISp-manifold.npy")


print(enc.shape)
# Out:
# (1261, 6)

# %%
import matplotlib.pyplot as plt

plt.scatter(enc[:, 0], enc[:, 1])
plt.title("VISp Encoding Manifold")
plt.xlabel("DC1")
plt.ylabel("DC2")
plt.show()
